# %%
from clients.zenodo_client import ZenodoClient
from clients.dryad_client import DryadClient

zenodo = ZenodoClient()
dryad = DryadClient()

df_zenodo = zenodo.search_to_df(query='"REFI-QDA" OR qdpx', page=1, size=10)
df_dryad = dryad.search_to_df(query='NVivo', page=1, per_page=10)

display(df_zenodo.head())
display(df_dryad.head())
