# %%
import requests
import pandas as pd

from modules.functions import search_to_df

# %%
q = 'interview transcript'

# %%
df, total = search_to_df(q, page=1, size=20, open_access_only=True)

# %%
display(df)
# Out:
#           id                                              title  \
# 0   10555163  Transcript of an online interview with an expe...
# 1    8174461  Jeffrey Beall: South Asia has a worldwide repu...
# 2    4469568  Interview with Prof. Predrag Pejović on Comput...
# 3    7101606                tidyqpcr User Interview Transcripts
# 4   15694887                               Interview Transcript
# 5   13889634  Feedback from experts on participatory governance
# 6    7619012      Data set open access of Palm Oil Supply Chain
# 7   15058151  Challenges in data quality management for IoT-...
# 8   13836216  Transcript Strategic Alliances as a Catalyst f...
# 9    7544950    DEVELOPMENT OF LISTENING COMPREHENSION IN IELTS
# 10  10160351         Intervju med fokusgrupp (AI och bibliotek)
# 11   4311454           Example redacted SP interview transcript
# 12  17548501  Interview Transcript - The Role of Word of Mou...
# 13  15179943  Transcript of Interview in the topics of Predi...
# ...

# %%
total
# Out:
# 5765754

# %%
df.count()
# Out:
# id                       20
# title                    20
# publication_date         20
# doi                      20
# license                  20
# files_count              20
# file_names               20
# file_extensions          20
# file_download_links      20
# archive_download_link    20
# dtype: int64
